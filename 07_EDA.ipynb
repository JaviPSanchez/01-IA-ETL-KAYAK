# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('assets/df_cities_coords_temp.csv')
df
# Out:
#     Unnamed: 0                         Cities        lat       lon  temp_K  \
# 0            0              Mont Saint Michel  48.635954 -1.511460  276.98
# 1            1                        St Malo  48.649518 -2.026041  276.86
# 2            2                         Bayeux  49.276462 -0.702474  278.19
# 3            3                       Le Havre  49.493898  0.107973  275.30
# 4            4                          Rouen  49.440459  1.093966  274.74
# 5            5                          Paris  48.858890  2.320041  275.08
# 6            6                         Amiens  49.894171  2.295695  273.35
# 7            7                          Lille  50.636565  3.063528  273.65
# 8            8                     Strasbourg  48.584614  7.750713  269.36
# 9            9   Chateau du Haut Koenigsbourg  48.249523  7.345492  265.27
# 10          10                         Colmar  48.077752  7.357964  268.42
# ...

# %% [markdown]
# Top-16 destinations

# %%
fig = px.scatter_mapbox(df, lat="lat", lon="lon", color="temp_C", size="temp_K", zoom=4.5, mapbox_style="carto-positron")
fig.show()

# %% [markdown]
# Top-20 hotels in the area
