# %%
import os
import scrapy
import pandas as pd
from scrapy.crawler import CrawlerProcess

# %%
class OneweekSpider(scrapy.Spider):
    
    name = "oneweek"
    start_urls = ['https://one-week-in.com/35-cities-to-visit-in-france/']

    # Parse function for form request
    def parse(self, response):
        results = response.css('div.entry-content')
        
        print(results)
        
        for p in results:
        
            yield {
                'city': p.css('h2::text').getall(),
                'text': p.css('::text').getall()
            }

# %%
filename = "top_35_cities_to_visit_in_france.json"

# If file already exists, delete it before crawling (because Scrapy will concatenate the last and new results otherwise)
# if filename in os.listdir('./venv'):
#     os.remove('./venv' + filename)

# Declare a new CrawlerProcess with some settings
process = CrawlerProcess(settings = {
    'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)',
    "FEEDS": {
        filename : {"format": "json"},
    }
})

# Start the crawling using the spider you defined above
process.crawl(OneweekSpider)
process.start()
# Out:
# 2022-01-09 16:12:38 [scrapy.utils.log] INFO: Scrapy 2.5.0 started (bot: scrapybot)
# 2022-01-09 16:12:38 [scrapy.utils.log] INFO: Versions: lxml 4.6.3.0, libxml2 2.9.5, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.7.0, Python 3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Windows-10-10.0.19041-SP0
# 2022-01-09 16:12:38 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2022-01-09 16:12:38 [scrapy.crawler] INFO: Overridden settings:
# {'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2022-01-09 16:12:38 [scrapy.extensions.telnet] INFO: Telnet Password: bf13a6f536ea436c
# 2022-01-09 16:12:38 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2022-01-09 16:12:38 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-01-09 16:12:38 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-01-09 16:12:38 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-01-09 16:12:38 [scrapy.core.engine] INFO: Spider opened
# 2022-01-09 16:12:38 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-01-09 16:12:38 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6026
# ---------------------------------------------------------------------------
# ReactorNotRestartable                     Traceback (most recent call last)
# <ipython-input-14-d3e8b297bd7a> in <module>
#      15 # Start the crawling using the spider you defined above
#      16 process.crawl(OneweekSpider)
# ---> 17 process.start()
#
# ~\anaconda3\lib\site-packages\scrapy\crawler.py in start(self, stop_after_crawl)
#     325         tp.adjustPoolsize(maxthreads=self.settings.getint('REACTOR_THREADPOOL_MAXSIZE'))
#     326         reactor.addSystemEventTrigger('before', 'shutdown', self.stop)
# --> 327         reactor.run(installSignalHandlers=False)  # blocking call
#     328
#     329     def _graceful_stop_reactor(self):
#
# ~\anaconda3\lib\site-packages\twisted\internet\base.py in run(self, installSignalHandlers)
#    1315
#    1316     def run(self, installSignalHandlers: bool = True) -> None:
# -> 1317         self.startRunning(installSignalHandlers=installSignalHandlers)
#    1318         self.mainLoop()
#    1319
#
# ~\anaconda3\lib\site-packages\twisted\internet\base.py in startRunning(self, installSignalHandlers)
#    1297         """
#    1298         self._installSignalHandlers = installSignalHandlers
# -> 1299         ReactorBase.startRunning(cast(ReactorBase, self))
#    1300
#    1301     def _reallyStartRunning(self) -> None:
#
# ~\anaconda3\lib\site-packages\twisted\internet\base.py in startRunning(self)
#     841             raise error.ReactorAlreadyRunning()
#     842         if self._startedBefore:
# --> 843             raise error.ReactorNotRestartable()
#     844         self._started = True
#     845         self._stopped = False
#
# ReactorNotRestartable:

# %%
top_35 = pd.read_json('top_35_cities_to_visit_in_france.json')
top_35.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-224a1d12b031> in <module>
# ----> 1 top_35 = pd.read_json('top_35_cities_to_visit_in_france.json')
#       2 top_35.head()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     612
#     613     with json_reader:
# --> 614         return json_reader.read()
#     615
#     616
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in read(self)
#     746                 obj = self._get_object_parser(self._combine_lines(data_lines))
#     747         else:
# --> 748             obj = self._get_object_parser(self.data)
#     749         self.close()
#     750         return obj
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in _get_object_parser(self, json)
#     768         obj = None
#     769         if typ == "frame":
# --> 770             obj = FrameParser(json, **kwargs).parse()
#     771
#     772         if typ == "series" or obj is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in parse(self)
#     883
#     884         else:
# --> 885             self._parse_no_numpy()
#     886
#     887         if self.obj is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in _parse_no_numpy(self)
#    1138         if orient == "columns":
#    1139             self.obj = DataFrame(
# -> 1140                 loads(json, precise_float=self.precise_float), dtype=None
#    1141             )
#    1142         elif orient == "split":
#
# ValueError: Trailing data
