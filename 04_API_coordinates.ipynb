# %%
import pandas as pd
import requests

# %%
df = pd.read_csv('top_35_clean.csv', index_col=0)
df.head()
# Out:
#                Cities
# 0   Mont Saint Michel
# 1             St Malo
# 2              Bayeux
# 3            Le Havre
# 4               Rouen

# %%
response = requests.get("https://nominatim.openstreetmap.org/")
response
# Out:
# <Response [200]>

# %%
cities_list = []
for i, rows in df.iterrows():
    cities_list.append(rows[0])
cities_list

# %%
def get_coordinates(input_list):
    for city in input_list:
        gps = requests.get(f"https://nominatim.openstreetmap.org/search?city={city}&format=json&limit=1")
        data = gps.json()
        # print(data[0]['lat'], data[0]['lon'])
        yield data

# %%
get_coordinates(cities_list)
# Out:
# <generator object get_coordinates at 0x0000027AF84A8BC8>

# %%
# Print the values generated by get_lengths()
for value in get_coordinates(cities_list):
    print(value)
# Out:
# [{'place_id': 151486647, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 211285890, 'boundingbox': ['48.6349172', '48.637031', '-1.5133292', '-1.5094796'], 'lat': '48.6359541', 'lon': '-1.511459954959514', 'display_name': 'Mont Saint-Michel, Le Mont-Saint-Michel, Avranches, Manche, Normandie, France métropolitaine, 50170, France', 'class': 'place', 'type': 'islet', 'importance': 0.755436556781574}]
# [{'place_id': 121999, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 26691521, 'boundingbox': ['48.609518', '48.689518', '-2.0660409', '-1.9860409'], 'lat': '48.649518', 'lon': '-2.0260409', 'display_name': 'Saint-Malo, Ille-et-Vilaine, Bretagne, France métropolitaine, 35400, France', 'class': 'place', 'type': 'town', 'importance': 0.6764672172428952, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_place_town.p.20.png'}]
# ...
